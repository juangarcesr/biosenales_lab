# %% [markdown]
# Valentina Acevedo Mesa    CC 1000763409
#
# Juan José Garcés Rojas    CC 1007409305
#
# Luis Grajales Henández    CC 1003293560

# %% [markdown]
# ### 1. Descripción del proyecto:
# La técnica BCI (Brain-Computer-Interface) consiste en un sistema que codifica señales de la actividad cerebral en tiempo real para interactuar con el entorno sin necesidad de un movimiento real, que enfocado en la rehabilitación motora, la técnica de BCI se utiliza principalmente a reconocer y trasmitir la intención motora del paciente de mover una extremidad que perdió la movilidad a señales que producen una retroalimentación sensorial por medio de dispositivos como robots o estimulación eléctrica.
#
# El BCI tiene 2 enfoques principales que consisten un un enfoque asistivo y un enfoque rehabilitadora. En el primer enfoque, se busca sustituir las vías neuronales dañadas ofreciendo una comunicación constante en el control de dispositivos; el enfoque rehabilitadora busca recuperar las conexiones neuronales que se dañaron y restaurar funciones.
#
# Para lograr esto, la BCI se apoya directamente con la electroencefalografía (EEG) que puede ser invasiva o no invasiva.para la base de datos utilizada como referencia en el proyecto, se realiza un EEG no invasivo con una distribución 10-10 que permite una cantidad mayor de electrodos ubicados en el cuero cabelludo y, estos sensores van a capturar la actividad eléctrica de diferentes regiones del cerebro. Cuando se le pide al paciente realozar una actividad motora como lo es el movimiento de una mano o pie, aunque no logre realizarlo, el cerebro va a generar patrones que se relacionan a la tarea de movimiento asignada con un área del cerebro, específicamente a la corteza motora (canales C, según estudios previos, los más significativos son C3 y C4); los patrones reflejan cambios en las ondas cerebrales (alpha y beta).
#
# Para el proyecto, se va a trabajar con un estudio
#
# ![image.png](attachment:image.png)
#
# ### 3. Historia, uso y proyectos relacionados con BCI
# El desarrollo de las interfaces cerebro–computador (BCI) tiene sus ra ́ıces en los primeros estudios sobre la actividad electrica cerebral, iniciados con el electroencefalograma (EEG). Este fue registrado por primera vez por Hans Berger en 1924, permitiendo identificar las ondas alfa y beta, lo que marcó un antes y un después en la comprensión del funcionamiento cerebral. En 1930, Berger publicó su trabajo “Uber das Elektrenkephalogramm des Menschen”, donde presentó oficialmente sus hallazgos [1].
#
# El descubrimiento del EEG fue un paso previo fundamental para el desarrollo de los sistemas BCI. No obstante, sus antecedentes se remontan al siglo XIX, cuando Richard Caton registro señales eléctricas en cerebros de animales y publicó sus resultados en 1875 en el British Medical Journal. Paralelamente, los cient ́ıficos polacos Napoleon Nikodem Cybulski y Adolf Beck realizaron experimentos similares, y en 1913, Vladimir Pravdicz-Neminski describio distintos tipos de actividad bioelectrica cerebral, a la que llamó “electrocerebrograma”  ́[1].
#
# Estas investigaciones fueron las bases para que, decadas después, los científicos imaginaran la posibilidad de comunicar directamente el cerebro con una maquina. En 1973, el investigador Jacques J. Vidal, de la Universidad de California, adoptó por primera vez el termino Brain–Computer Interface (BCI) y propuso usar senales EEG para controlar computadoras y prótesis, marcando el inicio formal de esta tecnología [2].
#
# A finales de los anos 80, Farwell y Donchin (1988) desarrollaron el primer sistema funcional, el “P300 Speller”, que permitía escribir letras mediante los potenciales evocados del EEG. En la decada de 1990, Jonathan Wolpaw y su equipo en EE.UU. demostraron que era posible mover un cursor controlando la amplitud de las ondas, mientras que el grupo de Gert Pfurtscheller en Austria introdujo el prototipo de imaginacion motora, en el que el usuario imagina movimientos para generar patrones cerebrales espec ́ıficos. Desde entonces, las BCI han evolucionado rapidamente gracias al avance de la electronica, la neurociencia y la inteligencia artificial. A  principios del siglo XXI surgieron paradigmas basados en estímulos visuales (SSVEP), y mas recientemente, sistemas apoyados en aprendizaje profundo (Deep Learning), que mejoraron notablemente la precision en la decodificación de señales cerebrales [2].
#
#
# Actualmente, grandes compañías y centros de investigación están desarrollando BCIs invasivas y no invasivas para restaurar funciones motoras, permitir comunicación a personas paralizadas o controlar protesis robóticas. Aunque aún existen desafíos tecnológicos y éticos, los avances recientes confirman que la electroencefalografía fue el punto de partida esencial para convertir en realidad la comunicacion directa entre el cerebro y las maquinas [2].
#
# Algunos de los principales usos que se le confieren al BCI en avances significativos en los ultimos tiempos, se pueden evidenciar que uno de los principales usos esta relacionado con las tecnicas invasivas para decodificación de información motora con el uso de microelectrodos intracorticales con gran resolucion espacial y temporal, como se observa en la *Fig01* [2]. Otro uso que se ha evidenciado en articuo cient ́ıficos es la comunicación del lenguaje por medio de BCI invasivo, en donde se buscaba obtener una comunicación más fluída con la decodificacion de palabras maginadas por medio de microelectrodos instracorticales. Por otro lado, la tecnología BCI no-invasiva basada en EEG con e objetivo de identificar los distintos tipos de movimientos por medio de la detección no invasiva en miembros superiores [2].
#
# Ademas de las aplicaciones ya mencionadas, las interfaces cerebro-computadora (BCIs) tambien están comenzando a explorarse en el ámbito del entretenimiento. Actualmente existen dispositivos comerciales, como cascos con electrodos para uso doméstico, que permiten controlar juegos clásicos como Tetris mediante senales cerebrales. Asimismo, se espera que en los próximos años surjan avances significativos en experiencias inmersivas de realidad virtual basadas en BCIs [2]. Estas aplicaciones no se limitan al ocio. El uso de BCIs en Serious Games ha demostrado beneficios terapeuticos, especialmente para pacientes con trastornos neurologicos como epilepsia o déficit de atención.
#
# Los proyectos futuros estan relacionados con problemáticas identificadas a lo largo de resultados obtenidos en la experimentación actual. Se observó que existen riesgos quirúrgicos relacionados con dispositivos invasivos que requieren una craneotomía para dispositivos de ancho de banda (alta frecuencia de muestreo) que requieren altos niveles de potencia los cuales pueden afectar la vida util de la batería del dispositivo [3]. Otra de las problematicas identificadas corresponde a la imposibilidad del movimiento de la cabeza ya que mucho de los dispositivos cuentan con cableados lo cual se traduce en riesgos de infeccion por diversas reacciones del cuerpo relacionado con respuestas inmunes y el ruido asociado.
#
# Una de las alternativas probables a futuro es el uso de tecnologías no invasivas como el EEG debido a su alta frecuencia de muestreo, o el fNIRS (Luz IR para medición de oxigenacion cerebral) que cuenta con una mejor resolución espacial. Aunque el sistema no invasivo sea la mejor opción para tratamientos seguros, estas limitaciones se pueden ver expresadas en una baja precision y respuesta [3].
#
# Dentro de propuestas futuras se ha evaluado el BCI implantable por medio de venas (Stentrode) en donde se evita el uso de cirugía abierta. Este procedimiento se basa en el uso de electrodos introducidos en los vasos sanguíneos del cerebro por medio de un stent con electrodos. Con esta propuesta se obtuvo resultados de personas con ELA que escribían por medio de clicks mentales adicionandole un seguimiento ocular [3].
#
# A futuro se espera que el avance en el BCI se vea reflejado en el uso de electrodos mas densos y miniaturizados, BCI inalámbricas para evitar claves que comprometan la salud del paciente y el resultado final de la senal. Asimismo, el uso de implantes como por ejemplo el Stentrode [3].
#
# ### 4. Uso de coherencia y conectividad cerebral en BCI
#
# Las interfaces cerebro-computador (BCI) basadas en electroencefalografía (EEG) han evolucionado significativamente en los últimos años, pasando de enfoques centrados en características locales de la señal a metodologías que consideran la interacción entre distintas regiones del cerebro. En este contexto, la **coherencia y la conectividad cerebral** se han consolidado como herramientas fundamentales para el estudio de la actividad neuronal y la mejora del rendimiento de los sistemas BCI.
#
# De acuerdo con el artículo Recent applications of EEG-based brain-computer-interface (1), los sistemas BCI tienen como objetivo decodificar señales cerebrales para traducirlas en comandos que permitan la interacción con dispositivos externos. Sin embargo, debido a la naturaleza compleja, no estacionaria y de baja amplitud del EEG, los métodos tradicionales basados únicamente en características espectrales presentan limitaciones en términos de precisión.
#
# En este sentido, la **conectividad funcional** surge como una alternativa más representativa de la dinámica cerebral, ya que permite analizar la sincronización y la interacción entre diferentes regiones del cerebro. Esta se define como el estudio de las relaciones estadísticas entre señales neuronales, particularmente en términos de sincronización de fase o correlación temporal (2). Dentro de estas métricas, la **coherencia** es ampliamente utilizada, ya que cuantifica el grado de sincronización entre dos señales EEG en el dominio de la frecuencia, reflejando la comunicación funcional entre regiones cerebrales.
#
# El uso de conectividad en BCI permite capturar la naturaleza distribuida del procesamiento cerebral. En lugar de analizar canales de EEG de forma independiente, se construyen redes donde los nodos representan regiones cerebrales y las conexiones representan la interacción entre ellas. Este enfoque ha demostrado ser especialmente útil para tareas como la imaginación motora, el reconocimiento de estados cognitivos y la clasificación de señales neuronales, ya que proporciona información más significativa sobre la organización funcional del cerebro.
#
# Además, estudios recientes han demostrado que las características basadas en conectividad, como el **Phase Lag Index (PLI)**, la **correlación de envolvente de amplitud (AEC)** y otras métricas de sincronización, mejoran significativamente el rendimiento de los algoritmos de clasificación en comparación con métodos tradicionales [2]. Estas métricas permiten identificar patrones dinámicos de interacción cerebral que cambian en función del estado cognitivo o la tarea realizada.
#
# Por otra parte, Se ha observado que niveles más altos de conectividad están asociados con estados de mayor actividad cognitiva y conciencia, mientras que una reducción en la conectividad refleja alteraciones en la comunicación neuronal (3).
#
# # (figura BCI coherencia que está en la carpeta)
#
# La Figura  ilustra el proceso general de las BCI, incluyendo aplicaciones de las BCI en la atención médica. a El proceso completo de la BCI y los tipos de señales cerebrales. b El proceso de aplicaciones de BCI en rehabilitación. c La clasificación de las BCI basada en la comunicación diaria. d El papel de las neuronas inhibitorias en la epilepsia, señales EEG registradas en estados de convulsión, predicción de la epilepsia y marcadores fisiológicos de la epilepsia. e Las etapas del sueño y las formas de onda típicas durante el sueño. f Cuatro tipos de estimulación eléctrica del cerebro para la reanimación cerebral y enfermedades neurodegenerativas y g Otras aplicaciones de las BCI en el campo médico
#
# [1]: Recent applications of EEG-based brain-computer-interface
# Disponible en: https://pmc.ncbi.nlm.nih.gov/articles/PMC11931852/.
# [2]: Functional connectivity in EEG: a multiclass classification approach for disorders of consciousness
# Disponible en: https://pmc.ncbi.nlm.nih.gov/articles/PMC11985804.
# [3]: EEG Connectivity is an Objective Signature of Reduced Consciousness and Sleep Depth
# Disponible en: https://pubmed.ncbi.nlm.nih.gov/40911115/.

# %% [markdown]
# *PLAN DE ANÁLISIS*
#
#
# El plan de análisis que se va a utilizar sigue cuatro etapas
# descritas como: Adquisicion, preprocesamiento, Extracción de características y clasificacion y uso de pruebas estadisticas. Por lo tanto, se va a describir cada etapa de manera independiente.
#
#
# ***Adquisición:*** En la literatura se registra que el primer
# paso es la obtencion de los datos de la actividad cerebral aa partir de 64 electrodos según el sistema internacional 10-10 (excluyendo los electrodos Nz, F9, F10, FT9, FT10, A1, A2, TP9, TP10, P9 y P10), teniendo presente que las señales en los registros están numeradas del 0 al 63. Asimismo, identificando los electrodos sensoriomotores (C3, Cz, C4) ya que estos permiten detectar con mayor facilidad los ritmos μ y β de los movimientos e imaginacion motora.
#
# Ya teniendo los electrodos bien posicionados se registra con una frecuencia
# de muestreo adecuado (-) y se le indica al paciente realizar las cuatro tareas establecidas, Cada participante realizó 14 ensayos experimentales: dos ensayos de referencia de un minuto (uno con los ojos abiertos y otro con los ojos cerrados) y tres ensayos de dos minutos de cada una de las cuatro tareas siguientes:
#
# - [Tarea 1] Aparece un objetivo en el lado izquierdo o derecho de la pantalla. El sujeto abre y cierra el puño correspondiente hasta que el objetivo desaparece. Luego, el sujeto se relaja.
# - [Tarea 2] Aparece un objetivo en el lado izquierdo o derecho de la pantalla. El sujeto imagina abrir y cerrar el puño correspondiente hasta que el objetivo desaparece. Luego, el sujeto se relaja.
# - [Tarea 3] Aparece un objetivo en la parte superior o inferior de la pantalla. El sujeto abre y cierra ambos puños (si el objetivo está arriba) o ambos pies (si el objetivo está abajo) hasta que el objetivo desaparece. Luego, el sujeto se relaja.
# - [Tarea 4] Aparece un objetivo en la parte superior o inferior de la pantalla. El sujeto imagina abrir y cerrar ambos puños (si el objetivo está arriba) o ambos pies (si el objetivo está abajo) hasta que el objetivo desaparece. Luego, el sujeto se relaja.
#
# ***preprocesamiento:*** Se determinó teóricamente que la integridad de los resultados depende del adecuado acondicionamiento de la señal de entrada. Por ende limpiar la señal elimina resultados denominados falsos positivos que afectan la conectividad y la potencia. Para esto primero es indispensable utilizar filtros que atenuen la senal y eliminen ruido de fondo.
#
# Uno de los filtros mas ́útiles vienen siendo aquellos en donde se da el cambio de referencia original para la diferencia de voltaje de los electrodos ubicados en el cuero cabelludo. Existen varios tipos comunes como el CAR (Common Average Reference) en donde se toma el promedio general de todos los canales y se resta a cada uno, obteniendo asi mejoria en los patrones globales.
#
# **Extracción de características:** Para poder distinguir cuando el movimiento se realizo de forma real o por medio de imaginacion se usan medidas como la potencia de μ y β complementado con coherencia (sincronia) y patrones especiales (CSP).
#
# Se inicia con el analisis de la potencia (PSD) y ERD/ERS los cuales se complementan para identificar los cambios que existen de los ritmos cerebrales. El PSD da información de la cantidad de energia que tiene la senal cerebral en cada una de las frecuencias catalogadas y se obtiene por medio del metodo de Welch estableciendo asi el valor en Hz en donde se quiere determinar activacion neuronal, por tal razon es primordial empezar con este.
#
# Seguidamente del PSD, se realiza el ERD/ERS el cual permite observar los cambios de potencia respecto a un periodo base determinando asi cuando el cerebro se activo o cuando se desactivo. El ERD (Event - Related Desynchronization) establece cuando hay una activacion de la area estudiada, y el ERS (Event - Related Synchronization) determina cuando el cerebro se encuentra en fase de relajacion o recuperación. Si el resultado es negativo se dice que es un ERD y si es positivo un ERS.
# Para esto es importante tener en cuenta que μ y β estan relacionados con la imaginacion del movimiento y el control motor respectivamente. Se prosigue con la conectividad y coherencia los cuales son analisis complementarios, pero muy utiles, en donde se mide la sincronizacion de diferentes areas cerebrales.
# La idea principal es poder mostrar mayor activacion en las areas donde se este ejerciendo la acción que se obtiene de los electrodos, por tal razon es importante comprender la ubicacion de los electrodos. Finalemte, para la caracterizacion de la señal, el CSP (Common Spatial Patterns) sirve para clasificar las señales maximizando la diferencia de clases pudiendo distinguir de forma correcta cuando se esta ejecutando y cuando se esta imaginando.
#
# ***Clasificacion y uso de pruebas estadísticas:*** El soporte estad ́ıstico permite entender a efectividad del estudio por medio de comprobacion matematica.Dentro de las pruebas estad ́ısticas es necesario verificar normalidad de cada muestra y hacer una comparativa pareada (misma persona en dos condiciones diferentes) y asi establecer el uso de la prueba t - student o la de Man Withney. Si ya se esta hablando de comparaciones amplias (las 4 condiciones) se emplean metodos
#
# mas avanzados con el ANOVA y el test de Friedman.  ́
# Asimismo, la clasificaciones de las senales por medio  ̃
# de sistemas de entrenamiento como por ejemplo el uso
# de redes neuronales teniendo en cuenta los resultados
# obtenidos en la extraccion de caracter  ́  ́ısticas.

# %% [markdown]
# **HIPÓTESIS PROPUESTAS**
#
# 1RA: comparación de datos imaginarios de movimiento entre mano izquierda y mano derecha
#
# 2da:comparar si existen diferencias significativas entre movimiento real e imaginario para ambas manos
#
# 3ra: las pruebas estadóisticas por hipótesis sirven para determinar si hay diferencias significativas entre canales para reconocer el movimiento
#
# 4ta:Usar ERD/ERS para identificar en espectro de potencias los momentos específicos de las tareas

# %%
# !pip install mne

# %%
import mne
import os
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
import pandas as pd

# %% [markdown]
# les propongo dejar las hipótesis un poco más cortas de este tipo:
#
# **Hipótesis 1:** imaginación mano izquierda vs derecha
#
# H0: No existen diferencias significativas en la potencia de los ritmos mu y beta entre la imaginación de movimiento de la mano izquierda y la mano derecha en los canales sensoriomotores.
#
# H1: Sí existen diferencias significativas en la potencia de los ritmos mu y beta entre la imaginación de movimiento de la mano izquierda y la mano derecha en los canales sensoriomotores.
#
# **Hipótesis 2:** movimiento real vs imaginado
#
# H0: No existen diferencias significativas en la potencia de los ritmos mu y beta entre el movimiento real y la imaginación de movimiento.
#
# H1: Sí existen diferencias significativas en la potencia de los ritmos mu y beta entre el movimiento real y la imaginación de movimiento.
#
# **Hipótesis 3:** diferencias entre canales
#
# H0: No existen diferencias significativas entre los canales C3, Cz y C4 durante las tareas motoras.
#
# H1: Sí existen diferencias significativas entre los canales C3, Cz y C4 durante las tareas motoras.
#
# **Hipótesis 4:** ERD/ERS
#
# H0: No se observan cambios significativos de potencia respecto al reposo durante los periodos de tarea.
#
# H1: Sí se observan cambios significativos de potencia respecto al reposo durante los periodos de tarea

# %%
# !pip install mne tqdm
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 0.8/7.5 MB 1.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.5 MB 1.2 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/7.5 MB 1.2 MB/s eta 0:00:06
#    -------- ------------------------------- 1.6/7.5 MB 1.2 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/7.5 MB 1.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.1/7.5 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.4/7.5 MB 1.2 MB/s eta 0:00:05
#    ------------- -------------------------- 2.6/7.5 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 2.9/7.5 MB 1.2 MB/s eta 0:00:04
# ...

# %% [markdown]
# ## primero voy a intentar hacer el código para una parte de los datos para no exigir demás el pc jeje

# %%
import os
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import mne
from scipy.signal import welch
from tqdm import tqdm

# %%
# Ruta donde está el archivo .zip
ZIP_PATH = Path("eeg-motor-movementimagery-dataset-1.0.0.zip")

# Carpeta donde se extraerá la base de datos
DATA_DIR = Path("data")

# Carpeta donde guardaremos resultados intermedios
RESULTS_DIR = Path("resultados")

# Crear carpetas si no existen
DATA_DIR.mkdir(exist_ok=True)
RESULTS_DIR.mkdir(exist_ok=True)

print("Ruta del ZIP:", ZIP_PATH.resolve())
print("Carpeta de datos:", DATA_DIR.resolve())
print("Carpeta de resultados:", RESULTS_DIR.resolve())
# Out:
# Ruta del ZIP: C:\Users\ASUS\Downloads\eeg-motor-movementimagery-dataset-1.0.0.zip
# Carpeta de datos: C:\Users\ASUS\Downloads\data
# Carpeta de resultados: C:\Users\ASUS\Downloads\resultados

# %%
if ZIP_PATH.exists():
    print("Archivo ZIP encontrado correctamente.")
else:
    print("No se encontró el archivo ZIP. Revisa la ruta.")
# Out:
# Archivo ZIP encontrado correctamente.

# %%
with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    archivos_zip = zip_ref.namelist()

print(f"Cantidad total de archivos dentro del ZIP: {len(archivos_zip)}")

# Mostrar los primeros 30 archivos
for archivo in archivos_zip[:30]:
    print(archivo)
# Out:
# Cantidad total de archivos dentro del ZIP: 3169
# files/
# files/S001/
# files/S002/
# files/S003/
# files/S004/
# files/S005/
# files/S006/
# files/S007/
# files/S008/
# files/S009/
# files/S010/
# files/S011/
# files/S012/
# files/S013/
# files/S014/
# files/S015/
# files/S016/
# files/S017/
# files/S018/
# files/S019/
# files/S020/
# files/S021/
# files/S022/
# files/S023/
# files/S024/
# files/S025/
# files/S026/
# files/S027/
# files/S028/
# files/S029/

# %%
# Revisar si la carpeta de datos ya tiene contenido
if not any(DATA_DIR.iterdir()):
    print("Extrayendo archivos. Esto puede tardar unos minutos...")
    
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(DATA_DIR)
    
    print("Extracción finalizada.")
else:
    print("La carpeta de datos ya tiene archivos. No se vuelve a extraer.")
# Out:
# Extrayendo archivos. Esto puede tardar unos minutos...
# Extracción finalizada.

# %%
edf_files = list(DATA_DIR.rglob("*.edf"))

print(f"Cantidad de archivos EDF encontrados: {len(edf_files)}")

# Mostrar los primeros 10 archivos encontrados
for archivo in edf_files[:10]:
    print(archivo)
# Out:
# Cantidad de archivos EDF encontrados: 1526
# data\files\S001\S001R01.edf
# data\files\S001\S001R02.edf
# data\files\S001\S001R03.edf
# data\files\S001\S001R04.edf
# data\files\S001\S001R05.edf
# data\files\S001\S001R06.edf
# data\files\S001\S001R07.edf
# data\files\S001\S001R08.edf
# data\files\S001\S001R09.edf
# data\files\S001\S001R10.edf

# %%
# Tomamos solo los primeros 3 archivos EDF como prueba inicial
sample_files = edf_files[:3]

print("Archivos seleccionados para prueba:")
for archivo in sample_files:
    print(archivo)
# Out:
# Archivos seleccionados para prueba:
# data\files\S001\S001R01.edf
# data\files\S001\S001R02.edf
# data\files\S001\S001R03.edf

# %%
# Seleccionar el primer archivo de prueba
archivo_prueba = sample_files[0]

print("Leyendo archivo:", archivo_prueba)

raw = mne.io.read_raw_edf(archivo_prueba, preload=True, verbose=False)

print(raw)
# Out:
# Leyendo archivo: data\files\S001\S001R01.edf
# <RawEDF | S001R01.edf, 64 x 9760 (61.0 s), ~4.8 MiB, data loaded>

# %%
print("Número de canales:", len(raw.ch_names))
print("Nombres de canales:")
print(raw.ch_names)

print("\nFrecuencia de muestreo:")
print(raw.info["sfreq"])

print("\nDuración de la señal en segundos:")
print(raw.times[-1])
# Out:
# Número de canales: 64
# Nombres de canales:
# ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']
#
# Frecuencia de muestreo:
# 160.0
#
# Duración de la señal en segundos:
# 60.99375

# %%
# Duración que queremos visualizar
duracion_segundos = 5

# Tomar datos de los primeros 5 segundos
sfreq = raw.info["sfreq"]
n_muestras = int(duracion_segundos * sfreq)

data, times = raw[:, :n_muestras]

plt.figure(figsize=(12, 6))

# Graficamos solo los primeros 5 canales para no saturar
for i in range(5):
    plt.plot(times, data[i] + i * 0.0002, label=raw.ch_names[i])

plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud EEG")
plt.title("Primeros 5 segundos de señal EEG")
plt.legend()
plt.grid(True)
plt.show()

# %%
print(raw.annotations)
# Out:
# <Annotations | 1 segment: T0 (1)>

# %%
for onset, duration, description in zip(
    raw.annotations.onset,
    raw.annotations.duration,
    raw.annotations.description
):
    print(f"Inicio: {onset:.2f} s | Duración: {duration:.2f} s | Evento: {description}")
# Out:
# Inicio: 0.00 s | Duración: 60.20 s | Evento: T0

# %% [markdown]
# # sospechamos que elegimos un run en reposo, por eso vamos a explorar otros archivos porque paila analizar algo en reposo

# %%
for archivo in edf_files[:30]:
    print(archivo.name)
# Out:
# S001R01.edf
# S001R02.edf
# S001R03.edf
# S001R04.edf
# S001R05.edf
# S001R06.edf
# S001R07.edf
# S001R08.edf
# S001R09.edf
# S001R10.edf
# S001R11.edf
# S001R12.edf
# S001R13.edf
# S001R14.edf
# S002R01.edf
# S002R02.edf
# S002R03.edf
# S002R04.edf
# S002R05.edf
# S002R06.edf
# S002R07.edf
# S002R08.edf
# S002R09.edf
# S002R10.edf
# S002R11.edf
# S002R12.edf
# S002R13.edf
# S002R14.edf
# S003R01.edf
# S003R02.edf

# %%
# Runs de interés para mano izquierda y mano derecha
runs_interes = ["R03", "R04", "R07", "R08", "R11", "R12"]

edf_interes = [
    archivo for archivo in edf_files
    if any(run in archivo.name for run in runs_interes)
]

print(f"Cantidad de archivos EDF de interés encontrados: {len(edf_interes)}")

for archivo in edf_interes[:20]:
    print(archivo)
# Out:
# Cantidad de archivos EDF de interés encontrados: 654
# data\files\S001\S001R03.edf
# data\files\S001\S001R04.edf
# data\files\S001\S001R07.edf
# data\files\S001\S001R08.edf
# data\files\S001\S001R11.edf
# data\files\S001\S001R12.edf
# data\files\S002\S002R03.edf
# data\files\S002\S002R04.edf
# data\files\S002\S002R07.edf
# data\files\S002\S002R08.edf
# data\files\S002\S002R11.edf
# data\files\S002\S002R12.edf
# data\files\S003\S003R03.edf
# data\files\S003\S003R04.edf
# data\files\S003\S003R07.edf
# data\files\S003\S003R08.edf
# data\files\S003\S003R11.edf
# data\files\S003\S003R12.edf
# data\files\S004\S004R03.edf
# data\files\S004\S004R04.edf

# %%
archivo_prueba = None

for archivo in edf_interes:
    if "S001R03" in archivo.name:
        archivo_prueba = archivo
        break

print("Archivo de prueba seleccionado:")
print(archivo_prueba)
# Out:
# Archivo de prueba seleccionado:
# data\files\S001\S001R03.edf

# %%
raw = mne.io.read_raw_edf(archivo_prueba, preload=True, verbose=False)

print(raw)
print(raw.annotations)
# Out:
# <RawEDF | S001R03.edf, 64 x 20000 (125.0 s), ~9.8 MiB, data loaded>
# <Annotations | 30 segments: T0 (15), T1 (8), T2 (7)>

# %%
for onset, duration, description in zip(
    raw.annotations.onset,
    raw.annotations.duration,
    raw.annotations.description
):
    print(f"Inicio: {onset:.2f} s | Duración: {duration:.2f} s | Evento: {description}")
# Out:
# Inicio: 0.00 s | Duración: 4.20 s | Evento: T0
# Inicio: 4.20 s | Duración: 4.10 s | Evento: T2
# Inicio: 8.30 s | Duración: 4.20 s | Evento: T0
# Inicio: 12.50 s | Duración: 4.10 s | Evento: T1
# Inicio: 16.60 s | Duración: 4.20 s | Evento: T0
# Inicio: 20.80 s | Duración: 4.10 s | Evento: T1
# Inicio: 24.90 s | Duración: 4.20 s | Evento: T0
# Inicio: 29.10 s | Duración: 4.10 s | Evento: T2
# Inicio: 33.20 s | Duración: 4.20 s | Evento: T0
# Inicio: 37.40 s | Duración: 4.10 s | Evento: T2
# Inicio: 41.50 s | Duración: 4.20 s | Evento: T0
# Inicio: 45.70 s | Duración: 4.10 s | Evento: T1
# Inicio: 49.80 s | Duración: 4.20 s | Evento: T0
# Inicio: 54.00 s | Duración: 4.10 s | Evento: T1
# Inicio: 58.10 s | Duración: 4.20 s | Evento: T0
# Inicio: 62.30 s | Duración: 4.10 s | Evento: T2
# Inicio: 66.40 s | Duración: 4.20 s | Evento: T0
# Inicio: 70.60 s | Duración: 4.10 s | Evento: T1
# Inicio: 74.70 s | Duración: 4.20 s | Evento: T0
# Inicio: 78.90 s | Duración: 4.10 s | Evento: T2
# ...

# %%
def identificar_tipo_tarea(nombre_archivo):
    """
    Identifica si el archivo corresponde a movimiento real o imaginación motora.
    """
    
    if any(run in nombre_archivo for run in ["R03", "R07", "R11"]):
        return "movimiento_real"
    
    elif any(run in nombre_archivo for run in ["R04", "R08", "R12"]):
        return "imaginacion_motora"
    
    else:
        return "otro"

# %%
print(archivo_prueba.name)
print(identificar_tipo_tarea(archivo_prueba.name))
# Out:
# S001R03.edf
# movimiento_real

# %%
def extraer_sujeto_run(nombre_archivo):
    """
    Extrae el sujeto y el run desde nombres tipo S001R03.edf.
    """
    
    nombre = nombre_archivo.replace(".edf", "")
    
    sujeto = nombre[:4]   # S001
    run = nombre[4:]      # R03
    
    return sujeto, run

# %%
sujeto, run = extraer_sujeto_run(archivo_prueba.name)

print("Sujeto:", sujeto)
print("Run:", run)
print("Tipo de tarea:", identificar_tipo_tarea(archivo_prueba.name))
# Out:
# Sujeto: S001
# Run: R03
# Tipo de tarea: movimiento_real

# %%
print(raw.ch_names)
# Out:
# ['Fc5.', 'Fc3.', 'Fc1.', 'Fcz.', 'Fc2.', 'Fc4.', 'Fc6.', 'C5..', 'C3..', 'C1..', 'Cz..', 'C2..', 'C4..', 'C6..', 'Cp5.', 'Cp3.', 'Cp1.', 'Cpz.', 'Cp2.', 'Cp4.', 'Cp6.', 'Fp1.', 'Fpz.', 'Fp2.', 'Af7.', 'Af3.', 'Afz.', 'Af4.', 'Af8.', 'F7..', 'F5..', 'F3..', 'F1..', 'Fz..', 'F2..', 'F4..', 'F6..', 'F8..', 'Ft7.', 'Ft8.', 'T7..', 'T8..', 'T9..', 'T10.', 'Tp7.', 'Tp8.', 'P7..', 'P5..', 'P3..', 'P1..', 'Pz..', 'P2..', 'P4..', 'P6..', 'P8..', 'Po7.', 'Po3.', 'Poz.', 'Po4.', 'Po8.', 'O1..', 'Oz..', 'O2..', 'Iz..']

# %%
for i, canal in enumerate(raw.ch_names):
    print(i, canal)
# Out:
# 0 Fc5.
# 1 Fc3.
# 2 Fc1.
# 3 Fcz.
# 4 Fc2.
# 5 Fc4.
# 6 Fc6.
# 7 C5..
# 8 C3..
# 9 C1..
# 10 Cz..
# 11 C2..
# 12 C4..
# 13 C6..
# 14 Cp5.
# 15 Cp3.
# 16 Cp1.
# 17 Cpz.
# 18 Cp2.
# 19 Cp4.
# 20 Cp6.
# 21 Fp1.
# 22 Fpz.
# 23 Fp2.
# 24 Af7.
# 25 Af3.
# 26 Afz.
# 27 Af4.
# 28 Af8.
# 29 F7..
# 30 F5..
# 31 F3..
# 32 F1..
# 33 Fz..
# 34 F2..
# 35 F4..
# 36 F6..
# 37 F8..
# 38 Ft7.
# 39 Ft8.
# 40 T7..
# 41 T8..
# 42 T9..
# 43 T10.
# 44 Tp7.
# 45 Tp8.
# 46 P7..
# 47 P5..
# 48 P3..
# 49 P1..
# 50 Pz..
# 51 P2..
# 52 P4..
# 53 P6..
# 54 P8..
# 55 Po7.
# 56 Po3.
# 57 Poz.
# 58 Po4.
# 59 Po8.
# 60 O1..
# 61 Oz..
# 62 O2..
# 63 Iz..

# %%
def limpiar_nombres_canales(raw):
    """
    Limpia los nombres de los canales eliminando puntos y espacios.
    Ejemplo: 'C3..' -> 'C3'
    """
    
    nuevos_nombres = {}

    for canal in raw.ch_names:
        canal_limpio = canal.replace(".", "").replace(" ", "")
        nuevos_nombres[canal] = canal_limpio

    raw.rename_channels(nuevos_nombres)

    return raw

# %%
raw_limpio = raw.copy()
raw_limpio = limpiar_nombres_canales(raw_limpio)

print(raw_limpio.ch_names)
# Out:
# ['Fc5', 'Fc3', 'Fc1', 'Fcz', 'Fc2', 'Fc4', 'Fc6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'Cp5', 'Cp3', 'Cp1', 'Cpz', 'Cp2', 'Cp4', 'Cp6', 'Fp1', 'Fpz', 'Fp2', 'Af7', 'Af3', 'Afz', 'Af4', 'Af8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'Ft7', 'Ft8', 'T7', 'T8', 'T9', 'T10', 'Tp7', 'Tp8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'Po7', 'Po3', 'Poz', 'Po4', 'Po8', 'O1', 'Oz', 'O2', 'Iz']

# %%
canales_interes = ["C3", "Cz", "C4"]

# %%
for canal in canales_interes:
    if canal in raw_limpio.ch_names:
        print(f"{canal} encontrado")
    else:
        print(f"{canal} NO encontrado")
# Out:
# C3 encontrado
# Cz encontrado
# C4 encontrado

# %%
raw_canales = raw_limpio.copy().pick_channels(canales_interes)

print(raw_canales)
print(raw_canales.ch_names)
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# <RawEDF | S001R03.edf, 3 x 20000 (125.0 s), ~476 KiB, data loaded>
# ['C3', 'Cz', 'C4']

# %%
duracion_segundos = 10
sfreq = raw_canales.info["sfreq"]
n_muestras = int(duracion_segundos * sfreq)

data, times = raw_canales[:, :n_muestras]

plt.figure(figsize=(12, 5))

for i, canal in enumerate(raw_canales.ch_names):
    plt.plot(times, data[i] + i * 0.0002, label=canal)

plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud EEG")
plt.title("Señal cruda - canales C3, Cz y C4")
plt.legend()
plt.grid(True)
plt.show()

# %%
raw_filtrado = raw_canales.copy()

raw_filtrado.filter(
    l_freq=8,
    h_freq=30,
    fir_design="firwin",
    verbose=False
)

print(raw_filtrado)
# Out:
# <RawEDF | S001R03.edf, 3 x 20000 (125.0 s), ~476 KiB, data loaded>

# %%
data_filt, times = raw_filtrado[:, :n_muestras]

plt.figure(figsize=(12, 5))

for i, canal in enumerate(raw_filtrado.ch_names):
    plt.plot(times, data_filt[i] + i * 0.00005, label=canal)

plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud EEG filtrada")
plt.title("Señal filtrada 8-30 Hz - canales C3, Cz y C4")
plt.legend()
plt.grid(True)
plt.show()

# %%
eventos, event_id = mne.events_from_annotations(raw_filtrado, verbose=False)

print("Event ID:")
print(event_id)

print("\nPrimeros eventos:")
print(eventos[:10])
# Out:
# Event ID:
# {'T0': 1, 'T1': 2, 'T2': 3}
#
# Primeros eventos:
# [[   0    0    1]
#  [ 672    0    3]
#  [1328    0    1]
#  [2000    0    2]
#  [2656    0    1]
#  [3328    0    2]
#  [3984    0    1]
#  [4656    0    3]
#  [5312    0    1]
#  [5984    0    3]]

# %%
event_id_tareas = {
    "T1": event_id["T1"],
    "T2": event_id["T2"]
}

epocas = mne.Epochs(
    raw_filtrado,
    eventos,
    event_id=event_id_tareas,
    tmin=0,
    tmax=4,
    baseline=None,
    preload=True,
    verbose=False
)

print(epocas)
# Out:
# <Epochs | 15 events (all good), 0 – 4 s (baseline off), ~232 KiB, data loaded,
#  'T1': 8
#  'T2': 7>

# %%
print("Cantidad de épocas T1:", len(epocas["T1"]))
print("Cantidad de épocas T2:", len(epocas["T2"]))
# Out:
# Cantidad de épocas T1: 8
# Cantidad de épocas T2: 7

# %%
# Tomar una época de T1
epoca_t1 = epocas["T1"][0]

data_epoca = epoca_t1.get_data()[0]
times_epoca = epoca_t1.times

plt.figure(figsize=(12, 5))

for i, canal in enumerate(epocas.ch_names):
    plt.plot(times_epoca, data_epoca[i] + i * 0.00005, label=canal)

plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud EEG filtrada")
plt.title("Ejemplo de época T1 - Mano izquierda")
plt.legend()
plt.grid(True)
plt.show()

# %%
epoca_t2 = epocas["T2"][0]

data_epoca = epoca_t2.get_data()[0]
times_epoca = epoca_t2.times

plt.figure(figsize=(12, 5))

for i, canal in enumerate(epocas.ch_names):
    plt.plot(times_epoca, data_epoca[i] + i * 0.00005, label=canal)

plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud EEG filtrada")
plt.title("Ejemplo de época T2 - Mano derecha")
plt.legend()
plt.grid(True)
plt.show()

# %%
print(raw_limpio.ch_names)
print("Event ID:")
print(event_id)
print(epocas)
print("Cantidad de épocas T1:", len(epocas["T1"]))
print("Cantidad de épocas T2:", len(epocas["T2"]))
# Out:
# ['Fc5', 'Fc3', 'Fc1', 'Fcz', 'Fc2', 'Fc4', 'Fc6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'Cp5', 'Cp3', 'Cp1', 'Cpz', 'Cp2', 'Cp4', 'Cp6', 'Fp1', 'Fpz', 'Fp2', 'Af7', 'Af3', 'Afz', 'Af4', 'Af8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'Ft7', 'Ft8', 'T7', 'T8', 'T9', 'T10', 'Tp7', 'Tp8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'Po7', 'Po3', 'Poz', 'Po4', 'Po8', 'O1', 'Oz', 'O2', 'Iz']
# Event ID:
# {'T0': 1, 'T1': 2, 'T2': 3}
# <Epochs | 15 events (all good), 0 – 4 s (baseline off), ~232 KiB, data loaded,
#  'T1': 8
#  'T2': 7>
# Cantidad de épocas T1: 8
# Cantidad de épocas T2: 7

# %%
bandas = {
    "mu": (8, 13),
    "beta": (13, 30)
}

print(bandas)
# Out:
# {'mu': (8, 13), 'beta': (13, 30)}

# %%
datos_epocas = epocas.get_data()

print("Forma de datos_epocas:")
print(datos_epocas.shape)
# Out:
# Forma de datos_epocas:
# (15, 3, 641)

# %%
from scipy.signal import welch

# Frecuencia de muestreo
sfreq = epocas.info["sfreq"]

# Tomamos la primera época
datos_una_epoca = datos_epocas[0]

print("Forma de una época:")
print(datos_una_epoca.shape)
# Out:
# Forma de una época:
# (3, 641)

# %%
frecuencias, psd = welch(
    datos_una_epoca,
    fs=sfreq,
    nperseg=int(sfreq * 2),
    axis=1
)

print("Forma de frecuencias:")
print(frecuencias.shape)

print("Forma de PSD:")
print(psd.shape)
# Out:
# Forma de frecuencias:
# (161,)
# Forma de PSD:
# (3, 161)

# %%
plt.figure(figsize=(10, 5))

for i, canal in enumerate(epocas.ch_names):
    plt.plot(frecuencias, psd[i], label=canal)

plt.xlim(0, 40)
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("PSD")
plt.title("PSD con Welch - una época de ejemplo")
plt.legend()
plt.grid(True)
plt.show()

# %%
def potencia_promedio_banda(frecuencias, psd_canal, fmin, fmax):
    """
    Calcula la potencia promedio de una PSD dentro de una banda de frecuencia.
    """
    
    indices_banda = (frecuencias >= fmin) & (frecuencias <= fmax)
    potencia = np.mean(psd_canal[indices_banda])
    
    return potencia

# %%
# Canal C3
psd_c3 = psd[0]

potencia_mu_c3 = potencia_promedio_banda(
    frecuencias,
    psd_c3,
    8,
    13
)

potencia_beta_c3 = potencia_promedio_banda(
    frecuencias,
    psd_c3,
    13,
    30
)

print("Potencia mu C3:", potencia_mu_c3)
print("Potencia beta C3:", potencia_beta_c3)
# Out:
# Potencia mu C3: 2.682608753066999e-11
# Potencia beta C3: 1.3309005579066102e-11

# %%
resultados = []

# Datos de todas las épocas
datos_epocas = epocas.get_data()

# Etiquetas de eventos por época
eventos_epocas = epocas.events[:, -1]

# Mapa inverso para saber si cada época es T1 o T2
event_id_inverso = {v: k for k, v in event_id_tareas.items()}

for idx_epoca, datos_epoca in enumerate(datos_epocas):
    
    codigo_evento = eventos_epocas[idx_epoca]
    evento = event_id_inverso[codigo_evento]
    
    if evento == "T1":
        mano = "izquierda"
    elif evento == "T2":
        mano = "derecha"
    else:
        mano = "desconocida"
    
    frecuencias, psd = welch(
        datos_epoca,
        fs=sfreq,
        nperseg=int(sfreq * 2),
        axis=1
    )
    
    for idx_canal, canal in enumerate(epocas.ch_names):
        
        psd_canal = psd[idx_canal]
        
        for nombre_banda, (fmin, fmax) in bandas.items():
            
            potencia = potencia_promedio_banda(
                frecuencias,
                psd_canal,
                fmin,
                fmax
            )
            
            resultados.append({
                "sujeto": sujeto,
                "run": run,
                "tipo_tarea": identificar_tipo_tarea(archivo_prueba.name),
                "evento": evento,
                "mano": mano,
                "canal": canal,
                "banda": nombre_banda,
                "potencia_promedio": potencia
            })

# %%
df_resultados = pd.DataFrame(resultados)

print(df_resultados.head())
print("\nCantidad de filas:", len(df_resultados))
# Out:
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
#
# Cantidad de filas: 90

# %%
print("Filas esperadas:", len(epocas) * len(epocas.ch_names) * len(bandas))
print("Filas obtenidas:", len(df_resultados))
# Out:
# Filas esperadas: 90
# Filas obtenidas: 90

# %%
resumen = df_resultados.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_promedio"].mean().reset_index()

print(resumen)
# Out:
#          tipo_tarea       mano canal banda  potencia_promedio
# 0   movimiento_real    derecha    C3  beta       1.104379e-11
# 1   movimiento_real    derecha    C3    mu       3.115834e-11
# 2   movimiento_real    derecha    C4  beta       8.519790e-12
# 3   movimiento_real    derecha    C4    mu       2.262427e-11
# 4   movimiento_real    derecha    Cz  beta       1.127134e-11
# 5   movimiento_real    derecha    Cz    mu       3.305877e-11
# 6   movimiento_real  izquierda    C3  beta       1.078393e-11
# 7   movimiento_real  izquierda    C3    mu       3.540386e-11
# 8   movimiento_real  izquierda    C4  beta       8.128205e-12
# 9   movimiento_real  izquierda    C4    mu       2.427385e-11
# 10  movimiento_real  izquierda    Cz  beta       1.112819e-11
# 11  movimiento_real  izquierda    Cz    mu       3.483004e-11

# %%
for banda in bandas.keys():
    df_banda = resumen[resumen["banda"] == banda]
    
    plt.figure(figsize=(8, 5))
    
    for mano in df_banda["mano"].unique():
        datos_mano = df_banda[df_banda["mano"] == mano]
        plt.plot(
            datos_mano["canal"],
            datos_mano["potencia_promedio"],
            marker="o",
            label=mano
        )
    
    plt.xlabel("Canal")
    plt.ylabel("Potencia promedio")
    plt.title(f"Potencia promedio en banda {banda} - {identificar_tipo_tarea(archivo_prueba.name)}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
ruta_salida = RESULTS_DIR / "resultados_S001R03.csv"

df_resultados.to_csv(ruta_salida, index=False)

print("Archivo guardado en:")
print(ruta_salida.resolve())
# Out:
# Archivo guardado en:
# C:\Users\ASUS\Downloads\resultados\resultados_S001R03.csv

# %%
print(datos_epocas.shape)
print("Forma de PSD:")
print(psd.shape)
print(df_resultados.head())
print("Cantidad de filas:", len(df_resultados))
print(resumen)
# Out:
# (15, 3, 641)
# Forma de PSD:
# (3, 161)
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
# Cantidad de filas: 90
#          tipo_tarea       mano canal banda  potencia_promedio
# 0   movimiento_real    derecha    C3  beta       1.104379e-11
# 1   movimiento_real    derecha    C3    mu       3.115834e-11
# 2   movimiento_real    derecha    C4  beta       8.519790e-12
# 3   movimiento_real    derecha    C4    mu       2.262427e-11
# 4   movimiento_real    derecha    Cz  beta       1.127134e-11
# 5   movimiento_real    derecha    Cz    mu       3.305877e-11
# ...

# %%
def procesar_archivo_edf(
    ruta_archivo,
    canales_interes=["C3", "Cz", "C4"],
    bandas={"mu": (8, 13), "beta": (13, 30)},
    tmin=0,
    tmax=4,
    l_freq=8,
    h_freq=30
):
    """
    Procesa un archivo EDF de EEG y extrae la potencia promedio por banda,
    canal, condición y mano.

    Parámetros:
    -----------
    ruta_archivo : Path
        Ruta del archivo EDF.
    canales_interes : list
        Canales EEG que se van a analizar.
    bandas : dict
        Bandas de frecuencia a analizar.
    tmin : float
        Tiempo inicial de la época.
    tmax : float
        Tiempo final de la época.
    l_freq : float
        Frecuencia inferior del filtro.
    h_freq : float
        Frecuencia superior del filtro.

    Retorna:
    --------
    df : pandas.DataFrame
        Dataframe con sujeto, run, tipo de tarea, evento, mano, canal, banda y potencia.
    """

    # Extraer nombre del archivo
    nombre_archivo = ruta_archivo.name

    # Extraer sujeto y run
    sujeto, run = extraer_sujeto_run(nombre_archivo)

    # Identificar tipo de tarea
    tipo_tarea = identificar_tipo_tarea(nombre_archivo)

    # Leer archivo EDF
    raw = mne.io.read_raw_edf(ruta_archivo, preload=True, verbose=False)

    # Limpiar nombres de canales
    raw = limpiar_nombres_canales(raw)

    # Verificar que existan los canales de interés
    canales_disponibles = [canal for canal in canales_interes if canal in raw.ch_names]

    if len(canales_disponibles) == 0:
        print(f"No se encontraron canales de interés en {nombre_archivo}")
        return pd.DataFrame()

    # Seleccionar canales
    raw = raw.pick_channels(canales_disponibles)

    # Filtrar señal
    raw.filter(
        l_freq=l_freq,
        h_freq=h_freq,
        fir_design="firwin",
        verbose=False
    )

    # Convertir anotaciones a eventos
    eventos, event_id = mne.events_from_annotations(raw, verbose=False)

    # Verificar que existan T1 y T2
    if "T1" not in event_id or "T2" not in event_id:
        print(f"El archivo {nombre_archivo} no tiene eventos T1 y T2.")
        return pd.DataFrame()

    event_id_tareas = {
        "T1": event_id["T1"],
        "T2": event_id["T2"]
    }

    # Crear épocas
    epocas = mne.Epochs(
        raw,
        eventos,
        event_id=event_id_tareas,
        tmin=tmin,
        tmax=tmax,
        baseline=None,
        preload=True,
        verbose=False
    )

    if len(epocas) == 0:
        print(f"No se pudieron crear épocas para {nombre_archivo}")
        return pd.DataFrame()

    # Frecuencia de muestreo
    sfreq = epocas.info["sfreq"]

    # Datos de épocas
    datos_epocas = epocas.get_data()

    # Etiquetas de eventos por época
    eventos_epocas = epocas.events[:, -1]

    # Mapa inverso de eventos
    event_id_inverso = {v: k for k, v in event_id_tareas.items()}

    resultados = []

    for idx_epoca, datos_epoca in enumerate(datos_epocas):

        codigo_evento = eventos_epocas[idx_epoca]
        evento = event_id_inverso[codigo_evento]

        if evento == "T1":
            mano = "izquierda"
        elif evento == "T2":
            mano = "derecha"
        else:
            mano = "desconocida"

        frecuencias, psd = welch(
            datos_epoca,
            fs=sfreq,
            nperseg=int(sfreq * 2),
            axis=1
        )

        for idx_canal, canal in enumerate(epocas.ch_names):

            psd_canal = psd[idx_canal]

            for nombre_banda, (fmin, fmax) in bandas.items():

                potencia = potencia_promedio_banda(
                    frecuencias,
                    psd_canal,
                    fmin,
                    fmax
                )

                resultados.append({
                    "sujeto": sujeto,
                    "run": run,
                    "tipo_tarea": tipo_tarea,
                    "evento": evento,
                    "mano": mano,
                    "canal": canal,
                    "banda": nombre_banda,
                    "potencia_promedio": potencia
                })

    df = pd.DataFrame(resultados)

    return df

# %%
df_prueba_funcion = procesar_archivo_edf(archivo_prueba)

print(df_prueba_funcion.head())
print("Cantidad de filas:", len(df_prueba_funcion))
# Out:
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
# Cantidad de filas: 90

# %%
print("Filas del cálculo manual:", len(df_resultados))
print("Filas de la función:", len(df_prueba_funcion))
# Out:
# Filas del cálculo manual: 90
# Filas de la función: 90

# %%
resumen_funcion = df_prueba_funcion.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_promedio"].mean().reset_index()

print(resumen_funcion)
# Out:
#          tipo_tarea       mano canal banda  potencia_promedio
# 0   movimiento_real    derecha    C3  beta       1.104379e-11
# 1   movimiento_real    derecha    C3    mu       3.115834e-11
# 2   movimiento_real    derecha    C4  beta       8.519790e-12
# 3   movimiento_real    derecha    C4    mu       2.262427e-11
# 4   movimiento_real    derecha    Cz  beta       1.127134e-11
# 5   movimiento_real    derecha    Cz    mu       3.305877e-11
# 6   movimiento_real  izquierda    C3  beta       1.078393e-11
# 7   movimiento_real  izquierda    C3    mu       3.540386e-11
# 8   movimiento_real  izquierda    C4  beta       8.128205e-12
# 9   movimiento_real  izquierda    C4    mu       2.427385e-11
# 10  movimiento_real  izquierda    Cz  beta       1.112819e-11
# 11  movimiento_real  izquierda    Cz    mu       3.483004e-11

# %%
archivos_s001 = [
    archivo for archivo in edf_interes
    if "S001" in archivo.name
]

print("Archivos encontrados para S001:")

for archivo in archivos_s001:
    print(archivo.name)
# Out:
# Archivos encontrados para S001:
# S001R03.edf
# S001R04.edf
# S001R07.edf
# S001R08.edf
# S001R11.edf
# S001R12.edf

# %%
dataframes_s001 = []

for archivo in tqdm(archivos_s001):
    df_temp = procesar_archivo_edf(archivo)

    if not df_temp.empty:
        dataframes_s001.append(df_temp)

df_s001 = pd.concat(dataframes_s001, ignore_index=True)

print(df_s001.head())
print("Cantidad total de filas S001:", len(df_s001))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  33%|███▎      | 2/6 [00:00<00:00, 13.28it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  67%|██████▋   | 4/6 [00:00<00:00,  6.92it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  83%|████████▎ | 5/6 [00:00<00:00,  6.61it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 100%|██████████| 6/6 [00:00<00:00,  6.86it/s]
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# ...

# %%
resumen_s001 = df_s001.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_promedio"].mean().reset_index()

print(resumen_s001)
# Out:
#             tipo_tarea       mano canal banda  potencia_promedio
# 0   imaginacion_motora    derecha    C3  beta       9.862102e-12
# 1   imaginacion_motora    derecha    C3    mu       3.008963e-11
# 2   imaginacion_motora    derecha    C4  beta       7.838948e-12
# 3   imaginacion_motora    derecha    C4    mu       2.439111e-11
# 4   imaginacion_motora    derecha    Cz  beta       1.009087e-11
# 5   imaginacion_motora    derecha    Cz    mu       3.034882e-11
# 6   imaginacion_motora  izquierda    C3  beta       1.053144e-11
# 7   imaginacion_motora  izquierda    C3    mu       3.227624e-11
# 8   imaginacion_motora  izquierda    C4  beta       7.483756e-12
# 9   imaginacion_motora  izquierda    C4    mu       1.891570e-11
# 10  imaginacion_motora  izquierda    Cz  beta       1.054824e-11
# 11  imaginacion_motora  izquierda    Cz    mu       2.848529e-11
# 12     movimiento_real    derecha    C3  beta       1.092875e-11
# ...

# %%
ruta_s001 = RESULTS_DIR / "resultados_S001.csv"

df_s001.to_csv(ruta_s001, index=False)

print("Resultados de S001 guardados en:")
print(ruta_s001.resolve())
# Out:
# Resultados de S001 guardados en:
# C:\Users\ASUS\Downloads\resultados\resultados_S001.csv

# %%
for tipo_tarea in resumen_s001["tipo_tarea"].unique():

    for banda in resumen_s001["banda"].unique():

        df_plot = resumen_s001[
            (resumen_s001["tipo_tarea"] == tipo_tarea) &
            (resumen_s001["banda"] == banda)
        ]

        plt.figure(figsize=(8, 5))

        for mano in df_plot["mano"].unique():

            datos_mano = df_plot[df_plot["mano"] == mano]

            plt.plot(
                datos_mano["canal"],
                datos_mano["potencia_promedio"],
                marker="o",
                label=mano
            )

        plt.xlabel("Canal")
        plt.ylabel("Potencia promedio")
        plt.title(f"S001 - {tipo_tarea} - Banda {banda}")
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
print(df_prueba_funcion.head())
print("Cantidad de filas:", len(df_prueba_funcion))
print("Archivos encontrados para S001:")
for archivo in archivos_s001:
    print(archivo.name)
print(df_s001.head())
print("Cantidad total de filas S001:", len(df_s001))
print(resumen_s001)
# Out:
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
# Cantidad de filas: 90
# Archivos encontrados para S001:
# S001R03.edf
# S001R04.edf
# S001R07.edf
# S001R08.edf
# S001R11.edf
# S001R12.edf
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# ...

# %%
sujetos_disponibles = sorted(list(set([
    archivo.name[:4] for archivo in edf_interes
])))

print("Cantidad de sujetos disponibles:", len(sujetos_disponibles))
print(sujetos_disponibles[:20])
# Out:
# Cantidad de sujetos disponibles: 109
# ['S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007', 'S008', 'S009', 'S010', 'S011', 'S012', 'S013', 'S014', 'S015', 'S016', 'S017', 'S018', 'S019', 'S020']

# %%
sujetos_piloto = sujetos_disponibles[:5]

print("Sujetos seleccionados para piloto:")
print(sujetos_piloto)
# Out:
# Sujetos seleccionados para piloto:
# ['S001', 'S002', 'S003', 'S004', 'S005']

# %%
archivos_piloto = [
    archivo for archivo in edf_interes
    if archivo.name[:4] in sujetos_piloto
]

print("Cantidad de archivos piloto:", len(archivos_piloto))

for archivo in archivos_piloto:
    print(archivo.name)
# Out:
# Cantidad de archivos piloto: 30
# S001R03.edf
# S001R04.edf
# S001R07.edf
# S001R08.edf
# S001R11.edf
# S001R12.edf
# S002R03.edf
# S002R04.edf
# S002R07.edf
# S002R08.edf
# S002R11.edf
# S002R12.edf
# S003R03.edf
# S003R04.edf
# S003R07.edf
# S003R08.edf
# S003R11.edf
# S003R12.edf
# S004R03.edf
# S004R04.edf
# S004R07.edf
# S004R08.edf
# S004R11.edf
# S004R12.edf
# S005R03.edf
# S005R04.edf
# S005R07.edf
# S005R08.edf
# S005R11.edf
# S005R12.edf

# %%
dataframes_piloto = []
errores_piloto = []

for archivo in tqdm(archivos_piloto):
    try:
        df_temp = procesar_archivo_edf(archivo)

        if not df_temp.empty:
            dataframes_piloto.append(df_temp)

    except Exception as e:
        errores_piloto.append({
            "archivo": archivo.name,
            "error": str(e)
        })

df_piloto = pd.concat(dataframes_piloto, ignore_index=True)

print("Procesamiento piloto finalizado.")
print("Cantidad de dataframes procesados:", len(dataframes_piloto))
print("Cantidad total de filas piloto:", len(df_piloto))
print("Cantidad de errores:", len(errores_piloto))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#   3%|▎         | 1/30 [00:00<00:03,  8.61it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  10%|█         | 3/30 [00:00<00:02, 12.45it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  17%|█▋        | 5/30 [00:00<00:01, 14.62it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
#  23%|██▎       | 7/30 [00:00<00:01, 12.93it/s]
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ...

# %%
df_errores_piloto = pd.DataFrame(errores_piloto)

if len(df_errores_piloto) > 0:
    print(df_errores_piloto)
else:
    print("No se presentaron errores en la muestra piloto.")
# Out:
# No se presentaron errores en la muestra piloto.

# %%
ruta_piloto = RESULTS_DIR / "resultados_piloto_S001_S005.csv"

df_piloto.to_csv(ruta_piloto, index=False)

print("Resultados piloto guardados en:")
print(ruta_piloto.resolve())
# Out:
# Resultados piloto guardados en:
# C:\Users\ASUS\Downloads\resultados\resultados_piloto_S001_S005.csv

# %%
print(df_piloto.head())
print("\nDimensiones del dataframe piloto:")
print(df_piloto.shape)
# Out:
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
#
# Dimensiones del dataframe piloto:
# (2700, 8)

# %%
resumen_piloto = df_piloto.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_promedio"].mean().reset_index()

print(resumen_piloto)
# Out:
#             tipo_tarea       mano canal banda  potencia_promedio
# 0   imaginacion_motora    derecha    C3  beta       6.234480e-12
# 1   imaginacion_motora    derecha    C3    mu       1.729003e-11
# 2   imaginacion_motora    derecha    C4  beta       5.485061e-12
# 3   imaginacion_motora    derecha    C4    mu       1.357928e-11
# 4   imaginacion_motora    derecha    Cz  beta       6.670290e-12
# 5   imaginacion_motora    derecha    Cz    mu       1.806131e-11
# 6   imaginacion_motora  izquierda    C3  beta       6.588846e-12
# 7   imaginacion_motora  izquierda    C3    mu       1.755887e-11
# 8   imaginacion_motora  izquierda    C4  beta       5.361832e-12
# 9   imaginacion_motora  izquierda    C4    mu       1.297709e-11
# 10  imaginacion_motora  izquierda    Cz  beta       7.145081e-12
# 11  imaginacion_motora  izquierda    Cz    mu       1.765749e-11
# 12     movimiento_real    derecha    C3  beta       5.942683e-12
# ...

# %%
resumen_piloto_sujeto = df_piloto.groupby(
    ["sujeto", "tipo_tarea", "mano", "canal", "banda"]
)["potencia_promedio"].mean().reset_index()

print(resumen_piloto_sujeto.head(20))
# Out:
#    sujeto          tipo_tarea       mano canal banda  potencia_promedio
# 0    S001  imaginacion_motora    derecha    C3  beta       9.862102e-12
# 1    S001  imaginacion_motora    derecha    C3    mu       3.008963e-11
# 2    S001  imaginacion_motora    derecha    C4  beta       7.838948e-12
# 3    S001  imaginacion_motora    derecha    C4    mu       2.439111e-11
# 4    S001  imaginacion_motora    derecha    Cz  beta       1.009087e-11
# 5    S001  imaginacion_motora    derecha    Cz    mu       3.034882e-11
# 6    S001  imaginacion_motora  izquierda    C3  beta       1.053144e-11
# 7    S001  imaginacion_motora  izquierda    C3    mu       3.227624e-11
# 8    S001  imaginacion_motora  izquierda    C4  beta       7.483756e-12
# 9    S001  imaginacion_motora  izquierda    C4    mu       1.891570e-11
# 10   S001  imaginacion_motora  izquierda    Cz  beta       1.054824e-11
# 11   S001  imaginacion_motora  izquierda    Cz    mu       2.848529e-11
# ...

# %%
for tipo_tarea in resumen_piloto["tipo_tarea"].unique():

    for banda in resumen_piloto["banda"].unique():

        df_plot = resumen_piloto[
            (resumen_piloto["tipo_tarea"] == tipo_tarea) &
            (resumen_piloto["banda"] == banda)
        ]

        plt.figure(figsize=(8, 5))

        for mano in df_plot["mano"].unique():

            datos_mano = df_plot[df_plot["mano"] == mano]

            plt.plot(
                datos_mano["canal"],
                datos_mano["potencia_promedio"],
                marker="o",
                label=mano
            )

        plt.xlabel("Canal")
        plt.ylabel("Potencia promedio")
        plt.title(f"Piloto S001-S005 - {tipo_tarea} - Banda {banda}")
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
df_piloto["potencia_log"] = np.log10(df_piloto["potencia_promedio"])

print(df_piloto.head())
# Out:
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio  \
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
#
#    potencia_log
# 0    -10.571443
# 1    -10.875854
# 2    -10.657534
# 3    -10.949112
# 4    -10.872223

# %%
resumen_piloto_log = df_piloto.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_log"].mean().reset_index()

print(resumen_piloto_log)
# Out:
#             tipo_tarea       mano canal banda  potencia_log
# 0   imaginacion_motora    derecha    C3  beta    -11.353442
# 1   imaginacion_motora    derecha    C3    mu    -10.943811
# 2   imaginacion_motora    derecha    C4  beta    -11.389653
# 3   imaginacion_motora    derecha    C4    mu    -11.029121
# 4   imaginacion_motora    derecha    Cz  beta    -11.298229
# 5   imaginacion_motora    derecha    Cz    mu    -10.905694
# 6   imaginacion_motora  izquierda    C3  beta    -11.325221
# 7   imaginacion_motora  izquierda    C3    mu    -10.923822
# 8   imaginacion_motora  izquierda    C4  beta    -11.400316
# 9   imaginacion_motora  izquierda    C4    mu    -11.053399
# 10  imaginacion_motora  izquierda    Cz  beta    -11.266453
# 11  imaginacion_motora  izquierda    Cz    mu    -10.909801
# 12     movimiento_real    derecha    C3  beta    -11.368963
# 13     movimiento_real    derecha    C3    mu    -10.987261
# 14     movimiento_real    derecha    C4  beta    -11.417975
# ...

# %%
for tipo_tarea in resumen_piloto_log["tipo_tarea"].unique():

    for banda in resumen_piloto_log["banda"].unique():

        df_plot = resumen_piloto_log[
            (resumen_piloto_log["tipo_tarea"] == tipo_tarea) &
            (resumen_piloto_log["banda"] == banda)
        ]

        plt.figure(figsize=(8, 5))

        for mano in df_plot["mano"].unique():

            datos_mano = df_plot[df_plot["mano"] == mano]

            plt.plot(
                datos_mano["canal"],
                datos_mano["potencia_log"],
                marker="o",
                label=mano
            )

        plt.xlabel("Canal")
        plt.ylabel("log10(Potencia promedio)")
        plt.title(f"Piloto S001-S005 - {tipo_tarea} - Banda {banda}")
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
print("Cantidad de sujetos disponibles:", len(sujetos_disponibles))
print(sujetos_disponibles[:20])
print("Cantidad de archivos piloto:", len(archivos_piloto))
print("Cantidad total de filas piloto:", len(df_piloto))
print("Cantidad de errores:", len(errores_piloto))
print(df_piloto.shape)
print(resumen_piloto_log)
# Out:
# Cantidad de sujetos disponibles: 109
# ['S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007', 'S008', 'S009', 'S010', 'S011', 'S012', 'S013', 'S014', 'S015', 'S016', 'S017', 'S018', 'S019', 'S020']
# Cantidad de archivos piloto: 30
# Cantidad total de filas piloto: 2700
# Cantidad de errores: 0
# (2700, 9)
#             tipo_tarea       mano canal banda  potencia_log
# 0   imaginacion_motora    derecha    C3  beta    -11.353442
# 1   imaginacion_motora    derecha    C3    mu    -10.943811
# 2   imaginacion_motora    derecha    C4  beta    -11.389653
# 3   imaginacion_motora    derecha    C4    mu    -11.029121
# 4   imaginacion_motora    derecha    Cz  beta    -11.298229
# 5   imaginacion_motora    derecha    Cz    mu    -10.905694
# 6   imaginacion_motora  izquierda    C3  beta    -11.325221
# 7   imaginacion_motora  izquierda    C3    mu    -10.923822
# 8   imaginacion_motora  izquierda    C4  beta    -11.400316
# 9   imaginacion_motora  izquierda    C4    mu    -11.053399
# ...

# %%
orden_canales = ["C3", "Cz", "C4"]

resumen_piloto_log["canal"] = pd.Categorical(
    resumen_piloto_log["canal"],
    categories=orden_canales,
    ordered=True
)

resumen_piloto_log = resumen_piloto_log.sort_values(
    ["tipo_tarea", "banda", "mano", "canal"]
)

print(resumen_piloto_log)
# Out:
#             tipo_tarea       mano canal banda  potencia_log
# 0   imaginacion_motora    derecha    C3  beta    -11.353442
# 4   imaginacion_motora    derecha    Cz  beta    -11.298229
# 2   imaginacion_motora    derecha    C4  beta    -11.389653
# 6   imaginacion_motora  izquierda    C3  beta    -11.325221
# 10  imaginacion_motora  izquierda    Cz  beta    -11.266453
# 8   imaginacion_motora  izquierda    C4  beta    -11.400316
# 1   imaginacion_motora    derecha    C3    mu    -10.943811
# 5   imaginacion_motora    derecha    Cz    mu    -10.905694
# 3   imaginacion_motora    derecha    C4    mu    -11.029121
# 7   imaginacion_motora  izquierda    C3    mu    -10.923822
# 11  imaginacion_motora  izquierda    Cz    mu    -10.909801
# 9   imaginacion_motora  izquierda    C4    mu    -11.053399
# 12     movimiento_real    derecha    C3  beta    -11.368963
# 16     movimiento_real    derecha    Cz  beta    -11.287150
# 14     movimiento_real    derecha    C4  beta    -11.417975
# ...

# %%
for tipo_tarea in resumen_piloto_log["tipo_tarea"].unique():

    for banda in resumen_piloto_log["banda"].unique():

        df_plot = resumen_piloto_log[
            (resumen_piloto_log["tipo_tarea"] == tipo_tarea) &
            (resumen_piloto_log["banda"] == banda)
        ]

        plt.figure(figsize=(8, 5))

        for mano in ["izquierda", "derecha"]:

            datos_mano = df_plot[df_plot["mano"] == mano]

            plt.plot(
                datos_mano["canal"],
                datos_mano["potencia_log"],
                marker="o",
                label=mano
            )

        plt.xlabel("Canal")
        plt.ylabel("log10(Potencia promedio)")
        plt.title(f"Piloto S001-S005 - {tipo_tarea} - Banda {banda}")
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
df_piloto["potencia_db"] = 10 * np.log10(df_piloto["potencia_promedio"])

print(df_piloto.head())
# Out:
#   sujeto  run       tipo_tarea evento     mano canal banda  potencia_promedio  \
# 0   S001  R03  movimiento_real     T2  derecha    C3    mu       2.682609e-11
# 1   S001  R03  movimiento_real     T2  derecha    C3  beta       1.330901e-11
# 2   S001  R03  movimiento_real     T2  derecha    Cz    mu       2.200219e-11
# 3   S001  R03  movimiento_real     T2  derecha    Cz  beta       1.124315e-11
# 4   S001  R03  movimiento_real     T2  derecha    C4    mu       1.342076e-11
#
#    potencia_log  potencia_db
# 0    -10.571443  -105.714427
# 1    -10.875854  -108.758544
# 2    -10.657534  -106.575341
# 3    -10.949112  -109.491121
# 4    -10.872223  -108.722229

# %%
resumen_piloto_db = df_piloto.groupby(
    ["tipo_tarea", "mano", "canal", "banda"]
)["potencia_db"].mean().reset_index()

resumen_piloto_db["canal"] = pd.Categorical(
    resumen_piloto_db["canal"],
    categories=orden_canales,
    ordered=True
)

resumen_piloto_db = resumen_piloto_db.sort_values(
    ["tipo_tarea", "banda", "mano", "canal"]
)

print(resumen_piloto_db)
# Out:
#             tipo_tarea       mano canal banda  potencia_db
# 0   imaginacion_motora    derecha    C3  beta  -113.534416
# 4   imaginacion_motora    derecha    Cz  beta  -112.982290
# 2   imaginacion_motora    derecha    C4  beta  -113.896534
# 6   imaginacion_motora  izquierda    C3  beta  -113.252211
# 10  imaginacion_motora  izquierda    Cz  beta  -112.664535
# 8   imaginacion_motora  izquierda    C4  beta  -114.003162
# 1   imaginacion_motora    derecha    C3    mu  -109.438108
# 5   imaginacion_motora    derecha    Cz    mu  -109.056944
# 3   imaginacion_motora    derecha    C4    mu  -110.291215
# 7   imaginacion_motora  izquierda    C3    mu  -109.238221
# 11  imaginacion_motora  izquierda    Cz    mu  -109.098014
# 9   imaginacion_motora  izquierda    C4    mu  -110.533995
# 12     movimiento_real    derecha    C3  beta  -113.689626
# 16     movimiento_real    derecha    Cz  beta  -112.871496
# 14     movimiento_real    derecha    C4  beta  -114.179748
# ...

# %%
for tipo_tarea in resumen_piloto_db["tipo_tarea"].unique():

    for banda in resumen_piloto_db["banda"].unique():

        df_plot = resumen_piloto_db[
            (resumen_piloto_db["tipo_tarea"] == tipo_tarea) &
            (resumen_piloto_db["banda"] == banda)
        ]

        plt.figure(figsize=(8, 5))

        for mano in ["izquierda", "derecha"]:

            datos_mano = df_plot[df_plot["mano"] == mano]

            plt.plot(
                datos_mano["canal"],
                datos_mano["potencia_db"],
                marker="o",
                label=mano
            )

        plt.xlabel("Canal")
        plt.ylabel("Potencia [dB]")
        plt.title(f"Piloto S001-S005 - {tipo_tarea} - Banda {banda}")
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
for tipo_tarea in df_piloto["tipo_tarea"].unique():

    for banda in df_piloto["banda"].unique():

        df_plot = df_piloto[
            (df_piloto["tipo_tarea"] == tipo_tarea) &
            (df_piloto["banda"] == banda)
        ].copy()

        df_plot["canal"] = pd.Categorical(
            df_plot["canal"],
            categories=orden_canales,
            ordered=True
        )

        plt.figure(figsize=(8, 5))

        df_plot.boxplot(
            column="potencia_db",
            by=["canal", "mano"],
            rot=45
        )

        plt.xlabel("Canal y mano")
        plt.ylabel("Potencia [dB]")
        plt.title(f"{tipo_tarea} - Banda {banda}")
        plt.suptitle("")
        plt.grid(True)
        plt.show()
